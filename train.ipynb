# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator


model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())
model.add(Dense(units = 128, activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
val_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('Dataset/train',
                                                 target_size = (64, 64),
                                                 batch_size = 8,
                                                 class_mode = 'binary')
val_set = val_datagen.flow_from_directory('Dataset/val',
                                            target_size = (64, 64),
                                            batch_size = 8,
                                            class_mode = 'binary')

model.fit_generator(training_set,
                         steps_per_epoch = 10,
                         epochs = 50,
                         validation_data = val_set,
                         validation_steps = 2)



model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Found 80 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 10/10 [==============================] - 4s 345ms/step - loss: 1.1092 - accuracy: 0.4535 - val_loss: 0.6425 - val_accuracy: 0.6250
# Epoch 2/50
# 10/10 [==============================] - 3s 311ms/step - loss: 0.6799 - accuracy: 0.5690 - val_loss: 0.5479 - val_accuracy: 0.8125
# Epoch 3/50
# 10/10 [==============================] - 3s 254ms/step - loss: 0.5598 - accuracy: 0.7689 - val_loss: 0.5639 - val_accuracy: 0.6875
# Epoch 4/50
# 10/10 [==============================] - 3s 309ms/step - loss: 0.5611 - accuracy: 0.7838 - val_loss: 0.4379 - val_accuracy: 0.9375
# Epoch 5/50
# 10/10 [==============================] - 3s 282ms/step - loss: 0.4371 - accuracy: 0.8185 - val_loss: 0.4771 - val_accuracy: 0.6875
# Epoch 6/50
# 10/10 [==============================] - 3s 287ms/step - loss: 0.4701 - accuracy: 0.7507 - val_loss: 0.3240 - val_accuracy: 0.8750
# Epoch 7/50
# 10/10 [==============================] - 3s 285ms/step - loss: 0.3504 - accuracy: 0.9289 - val_loss: 0.3250 - val_accuracy: 0.8750
# Epoch 8/50
# 10/10 [==============================] - 3s 284ms/step - loss: 0.3862 - accuracy: 0.7612 - val_loss: 0.2820 - val_accuracy: 0.8750
# Epoch 9/50
# 10/10 [==============================] - 3s 304ms/step - loss: 0.2416 - accuracy: 0.9245 - val_loss: 0.1770 - val_accuracy: 1.0000
# Epoch 10/50
# 10/10 [==============================] - 4s 369ms/step - loss: 0.2171 - accuracy: 0.9039 - val_loss: 0.1421 - val_accuracy: 1.0000
# Epoch 11/50
# 10/10 [==============================] - 3s 351ms/step - loss: 0.1483 - accuracy: 0.9650 - val_loss: 0.1962 - val_accuracy: 0.9375
# Epoch 12/50
# 10/10 [==============================] - 3s 321ms/step - loss: 0.2187 - accuracy: 0.9029 - val_loss: 0.1070 - val_accuracy: 1.0000
# Epoch 13/50
# 10/10 [==============================] - 3s 309ms/step - loss: 0.1077 - accuracy: 0.9793 - val_loss: 0.0861 - val_accuracy: 1.0000
# Epoch 14/50
# 10/10 [==============================] - 3s 324ms/step - loss: 0.1853 - accuracy: 0.9464 - val_loss: 0.0688 - val_accuracy: 1.0000
# Epoch 15/50
# 10/10 [==============================] - 3s 311ms/step - loss: 0.1287 - accuracy: 0.9704 - val_loss: 0.0880 - val_accuracy: 1.0000
# Epoch 16/50
# 10/10 [==============================] - 3s 309ms/step - loss: 0.0871 - accuracy: 0.9934 - val_loss: 0.1103 - val_accuracy: 0.9375
# Epoch 17/50
# 10/10 [==============================] - 3s 289ms/step - loss: 0.1093 - accuracy: 0.9719 - val_loss: 0.0358 - val_accuracy: 1.0000
# Epoch 18/50
# 10/10 [==============================] - 3s 325ms/step - loss: 0.0960 - accuracy: 0.9754 - val_loss: 0.0493 - val_accuracy: 1.0000
# Epoch 19/50
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0796 - accuracy: 0.9740 - val_loss: 0.1349 - val_accuracy: 0.9375
# Epoch 20/50
# 10/10 [==============================] - 4s 383ms/step - loss: 0.1188 - accuracy: 0.9656 - val_loss: 0.0372 - val_accuracy: 1.0000
# Epoch 21/50
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0479 - accuracy: 1.0000 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 22/50
# 10/10 [==============================] - 3s 356ms/step - loss: 0.0568 - accuracy: 0.9934 - val_loss: 0.0615 - val_accuracy: 1.0000
# Epoch 23/50
# 10/10 [==============================] - 3s 327ms/step - loss: 0.0523 - accuracy: 0.9864 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 24/50
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0687 - accuracy: 0.9911 - val_loss: 0.0311 - val_accuracy: 1.0000
# Epoch 25/50
# 10/10 [==============================] - 3s 309ms/step - loss: 0.0484 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 1.0000
# Epoch 26/50
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0684 - accuracy: 0.9606 - val_loss: 0.0412 - val_accuracy: 1.0000
# Epoch 27/50
# 10/10 [==============================] - 3s 315ms/step - loss: 0.0762 - accuracy: 0.9765 - val_loss: 0.0245 - val_accuracy: 1.0000
# Epoch 28/50
# 10/10 [==============================] - 4s 349ms/step - loss: 0.0602 - accuracy: 0.9864 - val_loss: 0.0684 - val_accuracy: 1.0000
# Epoch 29/50
# 10/10 [==============================] - 4s 389ms/step - loss: 0.0613 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 1.0000
# Epoch 30/50
# 10/10 [==============================] - 3s 340ms/step - loss: 0.0303 - accuracy: 0.9893 - val_loss: 0.0150 - val_accuracy: 1.0000
# Epoch 31/50
# 10/10 [==============================] - 3s 340ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 32/50
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0248 - accuracy: 0.9880 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 33/50
# 10/10 [==============================] - 4s 349ms/step - loss: 0.0355 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 34/50
# 10/10 [==============================] - 3s 328ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 35/50
# 10/10 [==============================] - 3s 314ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 36/50
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 37/50
# 10/10 [==============================] - 4s 396ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 38/50
# 10/10 [==============================] - 3s 332ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 39/50
# 10/10 [==============================] - 3s 261ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 40/50
# 10/10 [==============================] - 3s 306ms/step - loss: 0.0307 - accuracy: 0.9893 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 41/50
# 10/10 [==============================] - 3s 361ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 42/50
# 10/10 [==============================] - 3s 273ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 43/50
# 10/10 [==============================] - 3s 278ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 44/50
# 10/10 [==============================] - 3s 304ms/step - loss: 0.0177 - accuracy: 0.9965 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 45/50
# 10/10 [==============================] - 3s 313ms/step - loss: 0.0219 - accuracy: 0.9893 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 46/50
# 10/10 [==============================] - 3s 264ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 47/50
# 10/10 [==============================] - 3s 282ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 48/50
# 10/10 [==============================] - 3s 306ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 49/50
# 10/10 [==============================] - 3s 338ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 50/50
# 10/10 [==============================] - 3s 285ms/step - loss: 0.0658 - accuracy: 0.9536 - val_loss: 0.0043 - val_accuracy: 1.0000
# Saved model to disk
